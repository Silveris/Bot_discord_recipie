# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import dont_add

# %%
base_url = 'https://basicswithbabish.co/episodes'

# %%
# scrapes urls from main page

options = webdriver.ChromeOptions() 
options.add_argument("start-maximized")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
driver = webdriver.Chrome(options=options, executable_path=r'chromedriver.exe')

driver.get(base_url)
while True:
    try:
        driver.execute_script("return arguments[0].scrollIntoView(true);", WebDriverWait(driver, 5).until(EC.visibility_of_element_located((By.XPATH, "//div[@class='sqs-block-button-container--center']"))))
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//div[@class='sqs-block-button-container--center']"))).click()
        print("LOAD MORE RESULTS button clicked")
    except:
        break
        
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
# Out:
# LOAD MORE RESULTS button clicked
# LOAD MORE RESULTS button clicked
# LOAD MORE RESULTS button clicked
# LOAD MORE RESULTS button clicked
# LOAD MORE RESULTS button clicked
# LOAD MORE RESULTS button clicked
# LOAD MORE RESULTS button clicked

# %%
url_ends = soup.find('div', class_='summary-item-list-container').find_all('div', class_='summary-title')
list_url_ends = []
for a in url_ends:
    list_url_ends.append(a.a['href'])

# %%
list_url_ends
# Out:
# ['/basicsepisodes/cheese-fondue',
#  '/basicsepisodes/mochi-icecream',
#  '/basicsepisodes/onepot-pasta',
#  '/basicsepisodes/french-toast',
#  '/basicsepisodes/shakshuka',
#  '/basicsepisodes/macandcheese',
#  '/basicsepisodes/smokedribs',
#  '/basicsepisodes/coffeecake',
#  '/basicsepisodes/gnocchi',
#  '/basicsepisodes/pan-sauces',
#  '/basicsepisodes/chimichangas',
#  '/basicsepisodes/ice-cream-sandwiches',
#  '/basicsepisodes/hot-chicken',
#  '/basicsepisodes/latkes',
#  '/basicsepisodes/chickpeas',
#  '/basicsepisodes/shepherdspie',
#  '/basicsepisodes/sourdough-bread',
#  '/basicsepisodes/millionaires-shortbread',
#  '/basicsepisodes/chili-two-ways',
#  '/basicsepisodes/frenchonionsoup',
#  '/basicsepisodes/porchetta',
#  '/basicsepisodes/cornbread',
#  '/basicsepisodes/thanksgivingleftovers',
#  '/basicsepisodes/healthymeals2',
#  '/basicsepisodes/pies',
#  '/basicsepisodes/espressodrinks',
#  '/basicsepisodes/indianbreads',
#  '/basicsepisodes/poutine',
#  '/basicsepisodes/cajunfood',
#  '/basicsepisodes/panpizza',
#  '/basicsepisodes/carbonara',
#  '/basicsepisodes/generaltsoschicken',
#  '/basicsepisodes/treslechescake',
#  '/basicsepisodes/brownies',
#  '/basicsepisodes/healthymeals',
#  '/basicsepisodes/coffee',
#  '/basicsepisodes/pulledpork',
#  '/basicsepisodes/cheesdips',
#  '/basicsepisodes/quesadillas',
#  '/basicsepisodes/chickentikkamasala',
#  '/basicsepisodes/blendersoups',
#  '/basicsepisodes/potroast',
#  '/basicsepisodes/biggamesnacks',
#  '/basicsepisodes/bagels',
#  '/basicsepisodes/pasta2',
#  '/basicsepisodes/friedrice',
#  '/basicsepisodes/holidaycocktails',
#  '/basicsepisodes/charcuterieandcheeseboards',
#  '/basicsepisodes/thanksgivingsides',
#  '/basicsepisodes/donuts',
#  '/basicsepisodes/weeknightmeals-ahmph',
#  '/basicsepisodes/wholeporkloin',
#  '/basicsepisodes/tonkotsuramen',
#  '/basicsepisodes/kitchencare',
#  '/basicsepisodes/salad-nb7s3-3jkft',
#  '/basicsepisodes/sousvide-nb7s3',
#  '/basicsepisodes/tacos',
#  '/basicsepisodes/bread',
#  '/basicsepisodes/icecream',
#  '/basicsepisodes/barbecueporkchops',
#  '/basicsepisodes/burgers',
#  '/basicsepisodes/risotto',
#  '/basicsepisodes/fish',
#  '/basicsepisodes/grilling-5j345',
#  '/basicsepisodes/eggspart2',
#  '/basicsepisodes/2017/10/23/baressentials-7xwwz',
#  '/basicsepisodes/2017/10/23/baressentials',
#  '/basicsepisodes/2017/10/23/eggs',
#  '/basicsepisodes/2017/10/23/sauces-9w5tm-2njph-5ahwj-hsl7s-fh6cr-dfapr',
#  '/basicsepisodes/2017/10/23/sauces-9w5tm-2njph-5ahwj-hsl7s-fh6cr-6r8lw',
#  '/basicsepisodes/2017/10/23/sauces-9w5tm-2njph-5ahwj-hsl7s-fh6cr',
#  '/basicsepisodes/2017/10/23/sauces-9w5tm-2njph-5ahwj-hsl7s',
#  '/basicsepisodes/2017/10/23/sauces-9w5tm-2njph-5ahwj',
#  '/basicsepisodes/2017/10/23/sauces-9w5tm-2njph',
#  '/basicsepisodes/2017/10/23/sauces-9w5tm',
#  '/basicsepisodes/2017/10/23/sauces',
#  '/basicsepisodes/2017/10/11/introductiontools']

# %%
url_start = 'https://basicswithbabish.co'
list_of_recipes = []


print('looping through the urls and getting recipes')

for url_end in list_url_ends:
    url = url_start + url_end
    print(f'getting html from {url}')
    
    # opens the browser to get the html
    driver = webdriver.Chrome('chromedriver.exe')
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()
    
    # the bits we want
    try:
        recipe_title = soup.find('article').find('h1').text
        recipe_description = soup.find('article').find('h2').text
        ingredents_raw_soup = soup.find('article').find('div', class_='row').find_all('div', class_='col')[1]
        steps_raw_soup = soup.find('article').find('div', class_='row').find_all('div', class_='col')[2]

        # breakdown of the ingredents
        ingredents = []
        ingredents_midway = ingredents_raw_soup.find_all('p')
        for ingredent in ingredents_midway:
            ingredents.append(ingredent.text.replace('\xa0', ''))


        # breakdown of the steps
        steps = []
        steps_midway = steps_raw_soup.find_all('p')
        for step in steps_midway:
            steps.append(step.text.replace('\xa0', ''))

        # loads the recipe dict
        recipe = {
            'Title' : recipe_title
            ,'Author' : 'Babish'
            ,'Url' : url
            ,'Description' : recipe_description
            ,'Ingredents' : ingredents
            ,'Steps' : steps
        }

        print('appending recipe to the list')
        list_of_recipes.append(recipe)
# Out:
# looping through the urls and getting recipes
# getting html from https://basicswithbabish.co/basicsepisodes/cheese-fondue
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/mochi-icecream
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/onepot-pasta
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/french-toast
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/shakshuka
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/macandcheese
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/smokedribs
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/coffeecake
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/gnocchi
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/pan-sauces
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/chimichangas
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/ice-cream-sandwiches
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/hot-chicken
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/latkes
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/chickpeas
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/shepherdspie
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/sourdough-bread
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/millionaires-shortbread
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/chili-two-ways
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/frenchonionsoup
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/porchetta
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/cornbread
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/thanksgivingleftovers
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/healthymeals2
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/pies
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/espressodrinks
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/indianbreads
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/poutine
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/cajunfood
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/panpizza
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/carbonara
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/generaltsoschicken
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/treslechescake
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/brownies
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/healthymeals
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/coffee
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/pulledpork
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/cheesdips
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/quesadillas
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/chickentikkamasala
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/blendersoups
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/potroast
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/biggamesnacks
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/bagels
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/pasta2
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/friedrice
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/holidaycocktails
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/charcuterieandcheeseboards
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/thanksgivingsides
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/donuts
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/weeknightmeals-ahmph
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/wholeporkloin
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/tonkotsuramen
# appending recipe to the list
# getting html from https://basicswithbabish.co/basicsepisodes/kitchencare
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-e7967a9bc22c> in <module>
#      18     recipe_title = soup.find('article').find('h1').text
#      19     recipe_description = soup.find('article').find('h2').text
# ---> 20     ingredents_raw_soup = soup.find('article').find('div', class_='row').find_all('div', class_='col')[1]
#      21     steps_raw_soup = soup.find('article').find('div', class_='row').find_all('div', class_='col')[2]
#      22
#
# IndexError: list index out of range
